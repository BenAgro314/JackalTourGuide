# %% [markdown]
# # Jackal Tourguide Project
# ## Demonstrations of dashboard functionality

# %%
# %matplotlib inline
from src.dashboard import *

d = Dashboard() 
d.add_series(Series('s1',date = '2020-07-17-12-47-30'))
d.add_series(Series('s2', date='2020-07-17-13-39-30'))
d.init_display(1,2) # one row, two columns
d.add_plot(TranslationError)
d.add_plot(YawError)
d.show()
# Out:
# {u'c': (0, 0.75, 0.75), u'b': (0, 0, 1), u'g': (0, 0.5, 0), u'y': (0.75, 0.75, 0), u'k': (0, 0, 0), u'r': (1, 0, 0), u'm': (0.75, 0, 0.75)}
# 2 colors not specified, selecting randomly
# {u'c': (0, 0.75, 0.75), u'g': (0, 0.5, 0), u'y': (0.75, 0.75, 0), u'k': (0, 0, 0), u'm': (0.75, 0, 0.75)}
# 2 colors not specified, selecting randomly
# Series:
# 	- s2
# 	- s1
# Display shape: (1, 2)
# Plot Types:
# 	Translation Error, (x label: Distance Travelled (m), y label: Translation Error (m))
# 	Yaw Error, (x label: Distance Travelled (m), y label: Yaw Error (m))
# /usr/lib/python2.7/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print d
# Out:
# Series:
# 	- amcl
# 	- gmapping
# Display shape: (1, 2)
# Plot Types:
# 	Translation Error, (x label: Distance Travelled (m), y label: Translation Error (m))
# 	Yaw Error, (x label: Distance Travelled (m), y label: Yaw Error (m))

# %%
print d.get_series('amcl')
# Out:
# Name: amcl
# Query:
# 	latest_date: None
# 	localization_technique: amcl
# 	load_world: None
# 	class_method: None
# 	scenarios: []
# 	success_status: None
# 	tour_name: None
# 	filter_status: None
# 	localization_test: None
# 	earliest_date: None
# Run List:
# 	2020-07-14-08-55-47
# 	2020-07-14-08-10-37
# Colors:
# 	r
# 	g

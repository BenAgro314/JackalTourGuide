# %% [markdown]
# # Jackal Tourguide Project
# ## Demonstrations of dashboard functionality

# %%
# %matplotlib inline
from src.dashboard import *

d = Dashboard() 
d.add_series('s1',date = '2020-07-17-12-47-30')
d.add_series('s2', date='2020-07-17-13-39-30')
d.change_series('s2', Series('s3', date='2020-07-17-13-39-30'))
d.init_display(1,2) # one row, two columns
d.add_plot(TranslationError)
d.add_plot(YawError)
d.add_plot(PathDifference)
d.show()
# Out:
# 2 colors not specified, selecting randomly
# 2 colors not specified, selecting randomly
# 2 colors not specified, selecting randomly
# Too many plot types for desired display dimensions, automatically adding row to display. Please run Dashboard.resize(rows, cols) for different display size
# Series:
# 	- s3
# 	- s1
# Display shape: (2, 2)
# Plot Types:
# 	Translation Error, (x label: Distance Travelled (m), y label: Translation Error (m))
# 	Yaw Error, (x label: Distance Travelled (m), y label: Yaw Error (m))
# 	Path Difference, (x label: Series, y label: Average percent difference from optimal path length (%))
#
# Not enough plot types specified for the desired display dimensions. There will be blanks
# /usr/lib/python2.7/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print d
print d.display.plots[2].info()
# Out:
# Series:
# 	- s3
# 	- s1
# Display shape: (2, 2)
# Plot Types:
# 	Translation Error, (x label: Distance Travelled (m), y label: Translation Error (m))
# 	Yaw Error, (x label: Distance Travelled (m), y label: Yaw Error (m))
# 	Path Difference, (x label: Series, y label: Average percent difference from optimal path length (%))
#
# Series: s3 has a path that deviates 0.562 % from the optimal path
# Series: s1 has a path that deviates 0.333 % from the optimal path

# %%
print d.get_series('amcl')
# Out:
# Series name amcl not found in dashboard
# None

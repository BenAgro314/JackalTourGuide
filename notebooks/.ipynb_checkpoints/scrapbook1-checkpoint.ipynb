# %% [markdown]
# # Jackal Tourguide Project
# ## Demonstrations of dashboard functionality

# %%
from src.dashboard import *

d = Dashboard() 
d.add_series(Series('amcl', color_list = ['r','g','b'], localization_technique = 'amcl'))
d.add_series(Series('gmapping', color_list = ['b','k','tab:purple'], localization_technique = 'gmapping'))
d.init_display(1,2) # one row, two columns
d.add_plot(Plot.translation_error)
d.add_plot(Plot.yaw_error)
d.show()

# %%
print d
# Out:
# Series:
# 	- amcl
# 	- gmapping
# Display shape: (1, 2)
# Plot Types:
# 	translation_error
# 	yaw_error

# %%
print d.get_series('amcl')
# Out:
# Name: amcl
# Query:
# 	latest_date: None
# 	localization_technique: amcl
# 	load_world: None
# 	class_method: None
# 	scenarios: []
# 	success_status: None
# 	tour_name: None
# 	filter_status: None
# 	localization_test: None
# 	earliest_date: None
# Run List:
# 	2020-07-14-08-55-47
# 	2020-07-14-08-10-37
# Colors:
# 	r
# 	g
# 	b

# %% [markdown]
# # Jackal Tourguide Project
# ## Demonstrations of dashboard functionality

# %%
# %matplotlib inline
from src.dashboard import *

d = Dashboard() 
d.add_series('s1',date = '2020-07-17-12-47-30')
d.add_series('s2', date='2020-07-17-13-39-30')
d.change_series('s2', Series('s3', date='2020-07-17-13-39-30'))
d.init_display(1,2) # one row, two columns
d.add_plot(TranslationError)
d.add_plot(YawError)
d.show()
# Out:
# 2 colors not specified, selecting randomly
# 2 colors not specified, selecting randomly
# 2 colors not specified, selecting randomly
# Series:
# 	- s3
# 	- s1
# Display shape: (1, 2)
# Plot Types:
# 	Translation Error, (x label: Distance Travelled (m), y label: Translation Error (m))
# 	Yaw Error, (x label: Distance Travelled (m), y label: Yaw Error (m))
# /usr/lib/python2.7/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print d
print d.display.plots[0].info()
# Out:
# Series:
# 	- s3
# 	- s1
# Display shape: (1, 2)
# Plot Types:
# 	Translation Error, (x label: Distance Travelled (m), y label: Translation Error (m))
# 	Yaw Error, (x label: Distance Travelled (m), y label: Yaw Error (m))
#
# ['s3', 's1']
# Series: s3 has an average translation error of 0.09187545334971224
# Series: s1 has an average translation error of 0.07375152102092682
#
# [<src.dashboard.src.dashboard.TranslationError instance at 0x7efcd7cf2230>, <src.dashboard.src.dashboard.YawError instance at 0x7efcd7cf8e10>]

# %%
print d.get_series('amcl')
# Out:
# Name: amcl
# Query:
# 	latest_date: None
# 	localization_technique: amcl
# 	load_world: None
# 	class_method: None
# 	scenarios: []
# 	success_status: None
# 	tour_name: None
# 	filter_status: None
# 	localization_test: None
# 	earliest_date: None
# Run List:
# 	2020-07-14-08-55-47
# 	2020-07-14-08-10-37
# Colors:
# 	r
# 	g
